# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv(r"C:\Users\HARISH\OneDrive\Desktop\Global_Ecom_Analytics\3_SQL\data\online_retail_cleaning-2009-2010.csv",encoding='latin1')
# Out:
# C:\Users\HARISH\AppData\Local\Temp\ipykernel_18464\3400100884.py:1: DtypeWarning: Columns (0: Invoice, 1: Transaction_Type, 2: StockCode, 3: Description, 4: InvoiceDate, 5: Customer_Type, 6: Country) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1=pd.read_csv(r"C:\Users\HARISH\OneDrive\Desktop\Global_Ecom_Analytics\3_SQL\data\online_retail_cleaning-2009-2010.csv",encoding='latin1')

# %%
df2=pd.read_csv(r"C:\Users\HARISH\OneDrive\Desktop\Global_Ecom_Analytics\3_SQL\data\online_retail_cleaning-2010-2011.csv",encoding='latin1')

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Invoice           518596 non-null  str
#  1   Transaction_Type  518596 non-null  str
#  2   StockCode         518596 non-null  str
#  3   Description       515668 non-null  str
#  4   Quantity          518596 non-null  float64
#  5   InvoiceDate       518596 non-null  str
#  6   Price             518596 non-null  float64
#  7   Customer ID       410763 non-null  float64
#  8   Customer_Type     518596 non-null  str
#  9   Country           518596 non-null  str
# dtypes: float64(3), str(7)
# memory usage: 40.1 MB

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 541910 entries, 0 to 541909
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Invoice           536642 non-null  str
#  1   Transaction_Type  536642 non-null  str
#  2   StockCode         536642 non-null  str
#  3   Description       535188 non-null  str
#  4   Quantity          536642 non-null  float64
#  5   InvoiceDate       536642 non-null  str
#  6   Price             536642 non-null  float64
#  7   Customer ID       401605 non-null  float64
#  8   Customer_Type     536642 non-null  str
#  9   Country           536642 non-null  str
# dtypes: float64(3), str(7)
# memory usage: 41.3 MB

# %%
df=pd.concat([df1,df2],ignore_index=True)

# %%
df.head()
# Out:
#   Invoice Transaction_Type StockCode                          Description  \
# 0  489434             Sale     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1  489434             Sale    79323P                   PINK CHERRY LIGHTS
# 2  489434             Sale    79323W                  WHITE CHERRY LIGHTS
# 3  489434             Sale     22041         RECORD FRAME 7" SINGLE SIZE
# 4  489434             Sale     21232       STRAWBERRY CERAMIC TRINKET BOX
#
#    Quantity       InvoiceDate  Price  Customer ID Customer_Type  \
# 0      12.0  01-12-2009 07:45   6.95      13085.0    REGISTERED
# 1      12.0  01-12-2009 07:45   6.75      13085.0    REGISTERED
# 2      12.0  01-12-2009 07:45   6.75      13085.0    REGISTERED
# 3      48.0  01-12-2009 07:45   2.10      13085.0    REGISTERED
# 4      24.0  01-12-2009 07:45   1.25      13085.0    REGISTERED
#
#           Country
# 0  United Kingdom
# 1  United Kingdom
# 2  United Kingdom
# 3  United Kingdom
# 4  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 10 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Invoice           1055238 non-null  str
#  1   Transaction_Type  1055238 non-null  str
#  2   StockCode         1055238 non-null  str
#  3   Description       1050856 non-null  str
#  4   Quantity          1055238 non-null  float64
#  5   InvoiceDate       1055238 non-null  str
#  6   Price             1055238 non-null  float64
#  7   Customer ID       812368 non-null   float64
#  8   Customer_Type     1055238 non-null  str
#  9   Country           1055238 non-null  str
# dtypes: float64(3), str(7)
# memory usage: 81.4 MB

# %%
df.describe()
# Out:
#            Quantity         Price    Customer ID
# count  1.055238e+06  1.055238e+06  812368.000000
# mean   1.002209e+01  4.673714e+00   15317.796570
# std    1.736819e+02  1.242609e+02    1698.113489
# min   -8.099500e+04 -5.359436e+04   12346.000000
# 25%    1.000000e+00  1.250000e+00   13969.000000
# 50%    3.000000e+00  2.100000e+00   15245.000000
# 75%    1.000000e+01  4.150000e+00   16794.000000
# max    8.099500e+04  3.897000e+04   18287.000000

# %%
df.shape
# Out:
# (1067371, 10)

# %%
df.columns
# Out:
# Index(['Invoice', 'Transaction_Type', 'StockCode', 'Description', 'Quantity',
#        'InvoiceDate', 'Price', 'Customer ID', 'Customer_Type', 'Country'],
#       dtype='str')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1067371, step=1)

# %%
print("Test")
# Out:
# Test

# %%
df.describe()
# Out:
#            Quantity         Price    Customer ID
# count  1.055238e+06  1.055238e+06  812368.000000
# mean   1.002209e+01  4.673714e+00   15317.796570
# std    1.736819e+02  1.242609e+02    1698.113489
# min   -8.099500e+04 -5.359436e+04   12346.000000
# 25%    1.000000e+00  1.250000e+00   13969.000000
# 50%    3.000000e+00  2.100000e+00   15245.000000
# 75%    1.000000e+01  4.150000e+00   16794.000000
# max    8.099500e+04  3.897000e+04   18287.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1067371, step=1)

# %%
df[["Quantity","Price"]].head()
# Out:
#    Quantity  Price
# 0      12.0   6.95
# 1      12.0   6.75
# 2      12.0   6.75
# 3      48.0   2.10
# 4      24.0   1.25

# %%
quantity = df["Quantity"].to_numpy()
price=df["Price"].to_numpy()

# %%
quantity.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 quantity.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
revenue=quantity*price

# %%
revenue[:4]
# Out:
# array([ 83.4,  81. ,  81. , 100.8])

# %%
total = np.sum(revenue)

# %%
print(total)
# Out:
# nan

# %%
np.isnan(revenue).sum()
# Out:
# np.int64(12133)

# %%
np.nansum(revenue)
# Out:
# np.float64(19231800.518)

# %%
np.isnan(quantity).sum()
# Out:
# np.int64(12133)

# %%
np.isnan(price).sum()
# Out:
# np.int64(12133)

# %%
df[["Quantity","Price"]].isna().sum()
# Out:
# Quantity    12133
# Price       12133
# dtype: int64

# %%
df[df["Quantity"].isna() & df["Price"].isna()].shape
# Out:
# (12133, 10)

# %%
quantity.shape
# Out:
# (1067371,)

# %%
quantity.ndim
# Out:
# 1

# %%
quantity.dtype
# Out:
# dtype('float64')

# %%
price.dtype
# Out:
# dtype('float64')

# %%
np.sum(quantity)
# Out:
# np.float64(nan)

# %%
np.nansum(quantity).sum()
# Out:
# np.float64(10575687.0)

# %%
np.mean(quantity)
# Out:
# np.float64(nan)

# %%
np.nanmean(quantity)
# Out:
# np.float64(10.022086960477163)

# %%
Transaction_Type=np.where(
    quantity>0,
    "Sale",
    "Return"
)

# %%
Transaction_Type[:10]
# Out:
# array(['Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale',
#        'Sale', 'Sale'], dtype='<U6')

# %%
Transaction_Type=="Return"
# Out:
# array([False, False, False, ...,  True,  True,  True], shape=(1067371,))

# %%
np.unique(Transaction_Type,return_counts=True)
# Out:
# (array(['Return', 'Sale'], dtype='<U6'), array([  35022, 1032349]))

# %%
df["Transaction_Type"]=Transaction_Type

# %%
df.columns
# Out:
# Index(['Invoice', 'Transaction_Type', 'StockCode', 'Description', 'Quantity',
#        'InvoiceDate', 'Price', 'Customer ID', 'Customer_Type', 'Country'],
#       dtype='str')

# %%
df["Transaction_Type"].value_counts()
# Out:
# Transaction_Type
# Sale      1032349
# Return      35022
# Name: count, dtype: int64

# %%
conditions = [
    quantity>0,
    quantity<0,
    quantity==0
]
choices = [
    "Sale",
    "Return",
    "Zero Quantity"
]

# %%
Transaction_Status= np.select(
    conditions,
    choices,
    default="UnKnown"
)

# %%
np.unique(Transaction_Status,return_counts=True)
# Out:
# (array(['Return', 'Sale', 'UnKnown'], dtype='<U13'),
#  array([  22889, 1032349,   12133]))

# %%
np.sum(quantity==0)
# Out:
# np.int64(0)

# %%
np.sum(conditions)
# Out:
# np.int64(1055238)

# %%
np.sum(quantity<0)
# Out:
# np.int64(22889)

# %%
np.nanmean(quantity)
# Out:
# np.float64(10.022086960477163)

# %%
np.nanmin(quantity)
# Out:
# np.float64(-80995.0)

# %%
np.nanmax(quantity)
# Out:
# np.float64(80995.0)

# %%
df[df["Quantity"].isin([-80995,80995])]
# Out:
#          Invoice Transaction_Type StockCode                  Description  \
# 1060621   581483             Sale     23843  PAPER CRAFT , LITTLE BIRDIE
# 1060622  C581484           Return     23843  PAPER CRAFT , LITTLE BIRDIE
#
#          Quantity       InvoiceDate  Price  Customer ID Customer_Type  \
# 1060621   80995.0  09-12-2011 09:15   2.08      16446.0    REGISTERED
# 1060622  -80995.0  09-12-2011 09:27   2.08      16446.0    REGISTERED
#
#                 Country
# 1060621  United Kingdom
# 1060622  United Kingdom

# %%
np.nanstd(quantity)
# Out:
# np.float64(173.6818228253457)

# %%
np.sum(quantity<0)
# Out:
# np.int64(22889)

# %%
np.sum(quantity[quantity<0])
# Out:
# np.float64(-1061934.0)

# %%
abs(np.sum(quantity[quantity<0]))
# Out:
# np.float64(1061934.0)

# %%
np.unique(df["Country"].to_numpy())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 np.unique(df["Country"].to_numpy())
#
# File c:\Users\HARISH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\numpy\lib\_arraysetops_impl.py:296, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan, sorted)
#     294     if axis is not None:
#     295         normalize_axis_index(axis, ar.ndim)
# --> 296     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     297                     equal_nan=equal_nan, inverse_shape=ar.shape, axis=None,
#     298                     sorted=sorted)
#     299     return _unpack_tuple(ret)
#     301 # axis was specified and not None
#
# File c:\Users\HARISH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\numpy\lib\_arraysetops_impl.py:385, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan, inverse_shape, axis, sorted)
#     383     aux = ar[perm]
#     384 else:
# --> 385     ar.sort()
#     386     aux = ar
#     387 mask = np.empty(aux.shape, dtype=np.bool)
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
np.unique(df["Country"].to_numpy())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 np.unique(df["Country"].to_numpy())
#
# File c:\Users\HARISH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\numpy\lib\_arraysetops_impl.py:296, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan, sorted)
#     294     if axis is not None:
#     295         normalize_axis_index(axis, ar.ndim)
# --> 296     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     297                     equal_nan=equal_nan, inverse_shape=ar.shape, axis=None,
#     298                     sorted=sorted)
#     299     return _unpack_tuple(ret)
#     301 # axis was specified and not None
#
# File c:\Users\HARISH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\numpy\lib\_arraysetops_impl.py:385, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan, inverse_shape, axis, sorted)
#     383     aux = ar[perm]
#     384 else:
# --> 385     ar.sort()
#     386     aux = ar
#     387 mask = np.empty(aux.shape, dtype=np.bool)
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
df["Country"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
country=df["Country"].to_numpy(dtype=object)

# %%
np.unique(country)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 np.unique(country)
#
# File c:\Users\HARISH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\numpy\lib\_arraysetops_impl.py:296, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan, sorted)
#     294     if axis is not None:
#     295         normalize_axis_index(axis, ar.ndim)
# --> 296     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     297                     equal_nan=equal_nan, inverse_shape=ar.shape, axis=None,
#     298                     sorted=sorted)
#     299     return _unpack_tuple(ret)
#     301 # axis was specified and not None
#
# File c:\Users\HARISH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\numpy\lib\_arraysetops_impl.py:385, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan, inverse_shape, axis, sorted)
#     383     aux = ar[perm]
#     384 else:
# --> 385     ar.sort()
#     386     aux = ar
#     387 mask = np.empty(aux.shape, dtype=np.bool)
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
country=df["Country"].dropna().to_numpy()

# %%
np.unique(country)
# Out:
# array(['Australia', 'Austria', 'Bahrain', 'Belgium', 'Bermuda', 'Brazil',
#        'Canada', 'Channel Islands', 'Cyprus', 'Czech Republic', 'Denmark',
#        'EIRE', 'European Community', 'Finland', 'France', 'Germany',
#        'Greece', 'Hong Kong', 'Iceland', 'Israel', 'Italy', 'Japan',
#        'Korea', 'Lebanon', 'Lithuania', 'Malta', 'Netherlands', 'Nigeria',
#        'Norway', 'Poland', 'Portugal', 'RSA', 'Saudi Arabia', 'Singapore',
#        'Spain', 'Sweden', 'Switzerland', 'Thailand', 'USA',
#        'United Arab Emirates', 'United Kingdom', 'Unspecified',
#        'West Indies'], dtype=object)

# %%
np.unique(country)
# Out:
# array(['Australia', 'Austria', 'Bahrain', 'Belgium', 'Bermuda', 'Brazil',
#        'Canada', 'Channel Islands', 'Cyprus', 'Czech Republic', 'Denmark',
#        'EIRE', 'European Community', 'Finland', 'France', 'Germany',
#        'Greece', 'Hong Kong', 'Iceland', 'Israel', 'Italy', 'Japan',
#        'Korea', 'Lebanon', 'Lithuania', 'Malta', 'Netherlands', 'Nigeria',
#        'Norway', 'Poland', 'Portugal', 'RSA', 'Saudi Arabia', 'Singapore',
#        'Spain', 'Sweden', 'Switzerland', 'Thailand', 'USA',
#        'United Arab Emirates', 'United Kingdom', 'Unspecified',
#        'West Indies'], dtype=object)

# %%
len(np.unique(country))
# Out:
# 43

# %%
np.unique(country,return_counts=True)
# Out:
# (array(['Australia', 'Austria', 'Bahrain', 'Belgium', 'Bermuda', 'Brazil',
#         'Canada', 'Channel Islands', 'Cyprus', 'Czech Republic', 'Denmark',
#         'EIRE', 'European Community', 'Finland', 'France', 'Germany',
#         'Greece', 'Hong Kong', 'Iceland', 'Israel', 'Italy', 'Japan',
#         'Korea', 'Lebanon', 'Lithuania', 'Malta', 'Netherlands', 'Nigeria',
#         'Norway', 'Poland', 'Portugal', 'RSA', 'Saudi Arabia', 'Singapore',
#         'Spain', 'Sweden', 'Switzerland', 'Thailand', 'USA',
#         'United Arab Emirates', 'United Kingdom', 'Unspecified',
#         'West Indies'], dtype=object),
#  array([  1912,    938,    126,   3122,     34,     94,    228,   1663,
#           1157,     30,    817,  17844,     61,   1049,  14296,  17600,
#            663,    360,    253,    368,   1532,    582,     63,     58,
#            189,    299,   5139,     32,   1455,    535,   2608,    169,
#             10,    346,   3799,   1362,   3181,     76,    535,    500,
#         969347,    752,     54]))
