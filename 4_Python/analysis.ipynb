# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv(r"C:\Users\HARISH\OneDrive\Desktop\Global_Ecom_Analytics\3_SQL\data\online_retail_cleaning-2009-2010.csv",encoding='latin1')
# Out:
# C:\Users\HARISH\AppData\Local\Temp\ipykernel_18464\3400100884.py:1: DtypeWarning: Columns (0: Invoice, 1: Transaction_Type, 2: StockCode, 3: Description, 4: InvoiceDate, 5: Customer_Type, 6: Country) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1=pd.read_csv(r"C:\Users\HARISH\OneDrive\Desktop\Global_Ecom_Analytics\3_SQL\data\online_retail_cleaning-2009-2010.csv",encoding='latin1')

# %%
df2=pd.read_csv(r"C:\Users\HARISH\OneDrive\Desktop\Global_Ecom_Analytics\3_SQL\data\online_retail_cleaning-2010-2011.csv",encoding='latin1')

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Invoice           518596 non-null  str
#  1   Transaction_Type  518596 non-null  str
#  2   StockCode         518596 non-null  str
#  3   Description       515668 non-null  str
#  4   Quantity          518596 non-null  float64
#  5   InvoiceDate       518596 non-null  str
#  6   Price             518596 non-null  float64
#  7   Customer ID       410763 non-null  float64
#  8   Customer_Type     518596 non-null  str
#  9   Country           518596 non-null  str
# dtypes: float64(3), str(7)
# memory usage: 40.1 MB

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 541910 entries, 0 to 541909
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Invoice           536642 non-null  str
#  1   Transaction_Type  536642 non-null  str
#  2   StockCode         536642 non-null  str
#  3   Description       535188 non-null  str
#  4   Quantity          536642 non-null  float64
#  5   InvoiceDate       536642 non-null  str
#  6   Price             536642 non-null  float64
#  7   Customer ID       401605 non-null  float64
#  8   Customer_Type     536642 non-null  str
#  9   Country           536642 non-null  str
# dtypes: float64(3), str(7)
# memory usage: 41.3 MB

# %%
df=pd.concat([df1,df2],ignore_index=True)

# %%
df.head()
# Out:
#   Invoice Transaction_Type StockCode                          Description  \
# 0  489434             Sale     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1  489434             Sale    79323P                   PINK CHERRY LIGHTS
# 2  489434             Sale    79323W                  WHITE CHERRY LIGHTS
# 3  489434             Sale     22041         RECORD FRAME 7" SINGLE SIZE
# 4  489434             Sale     21232       STRAWBERRY CERAMIC TRINKET BOX
#
#    Quantity       InvoiceDate  Price  Customer ID Customer_Type  \
# 0      12.0  01-12-2009 07:45   6.95      13085.0    REGISTERED
# 1      12.0  01-12-2009 07:45   6.75      13085.0    REGISTERED
# 2      12.0  01-12-2009 07:45   6.75      13085.0    REGISTERED
# 3      48.0  01-12-2009 07:45   2.10      13085.0    REGISTERED
# 4      24.0  01-12-2009 07:45   1.25      13085.0    REGISTERED
#
#           Country
# 0  United Kingdom
# 1  United Kingdom
# 2  United Kingdom
# 3  United Kingdom
# 4  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 10 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Invoice           1055238 non-null  str
#  1   Transaction_Type  1055238 non-null  str
#  2   StockCode         1055238 non-null  str
#  3   Description       1050856 non-null  str
#  4   Quantity          1055238 non-null  float64
#  5   InvoiceDate       1055238 non-null  str
#  6   Price             1055238 non-null  float64
#  7   Customer ID       812368 non-null   float64
#  8   Customer_Type     1055238 non-null  str
#  9   Country           1055238 non-null  str
# dtypes: float64(3), str(7)
# memory usage: 81.4 MB

# %%
df.describe()
# Out:
#            Quantity         Price    Customer ID
# count  1.055238e+06  1.055238e+06  812368.000000
# mean   1.002209e+01  4.673714e+00   15317.796570
# std    1.736819e+02  1.242609e+02    1698.113489
# min   -8.099500e+04 -5.359436e+04   12346.000000
# 25%    1.000000e+00  1.250000e+00   13969.000000
# 50%    3.000000e+00  2.100000e+00   15245.000000
# 75%    1.000000e+01  4.150000e+00   16794.000000
# max    8.099500e+04  3.897000e+04   18287.000000

# %%
df.shape
# Out:
# (1067371, 10)

# %%
df.columns
# Out:
# Index(['Invoice', 'Transaction_Type', 'StockCode', 'Description', 'Quantity',
#        'InvoiceDate', 'Price', 'Customer ID', 'Customer_Type', 'Country'],
#       dtype='str')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1067371, step=1)

# %%
print("Test")
# Out:
# Test

# %%
df.describe()
# Out:
#            Quantity         Price    Customer ID
# count  1.055238e+06  1.055238e+06  812368.000000
# mean   1.002209e+01  4.673714e+00   15317.796570
# std    1.736819e+02  1.242609e+02    1698.113489
# min   -8.099500e+04 -5.359436e+04   12346.000000
# 25%    1.000000e+00  1.250000e+00   13969.000000
# 50%    3.000000e+00  2.100000e+00   15245.000000
# 75%    1.000000e+01  4.150000e+00   16794.000000
# max    8.099500e+04  3.897000e+04   18287.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1067371, step=1)

# %%
df[["Quantity","Price"]].head()
# Out:
#    Quantity  Price
# 0      12.0   6.95
# 1      12.0   6.75
# 2      12.0   6.75
# 3      48.0   2.10
# 4      24.0   1.25

# %%
quantity = df["Quantity"].to_numpy()
price=df["Price"].to_numpy()

# %%
quantity.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 quantity.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
revenue=quantity*price

# %%
revenue[:4]
# Out:
# array([ 83.4,  81. ,  81. , 100.8])

# %%
total = np.sum(revenue)

# %%
print(total)
# Out:
# nan

# %%
np.isnan(revenue).sum()
# Out:
# np.int64(12133)

# %%
np.nansum(revenue)
# Out:
# np.float64(19231800.518)

# %%
np.isnan(quantity).sum()
# Out:
# np.int64(12133)

# %%
np.isnan(price).sum()
# Out:
# np.int64(12133)

# %%
df[["Quantity","Price"]].isna().sum()
# Out:
# Quantity    12133
# Price       12133
# dtype: int64

# %%
df[df["Quantity"].isna() & df["Price"].isna()].shape
# Out:
# (12133, 10)

# %%
quantity.shape
# Out:
# (1067371,)

# %%
quantity.ndim
# Out:
# 1

# %%
quantity.dtype
# Out:
# dtype('float64')

# %%
price.dtype
# Out:
# dtype('float64')

# %%
np.sum(quantity)
# Out:
# np.float64(nan)

# %%
np.nansum(quantity).sum()
# Out:
# np.float64(10575687.0)

# %%
np.mean(quantity)
# Out:
# np.float64(nan)

# %%
np.nanmean(quantity)
# Out:
# np.float64(10.022086960477163)

# %%
Transaction_Type=np.where(
    quantity>0,
    "Sale",
    "Return"
)

# %%
Transaction_Type[:10]
# Out:
# array(['Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale',
#        'Sale', 'Sale'], dtype='<U6')

# %%
Transaction_Type=="Return"
# Out:
# array([False, False, False, ...,  True,  True,  True], shape=(1067371,))

# %%
np.unique(Transaction_Type,return_counts=True)
# Out:
# (array(['Return', 'Sale'], dtype='<U6'), array([  35022, 1032349]))

# %%
df["Transaction_Type"]=Transaction_Type

# %%
df.columns
# Out:
# Index(['Invoice', 'Transaction_Type', 'StockCode', 'Description', 'Quantity',
#        'InvoiceDate', 'Price', 'Customer ID', 'Customer_Type', 'Country'],
#       dtype='str')

# %%
df["Transaction_Type"].value_counts()
# Out:
# Transaction_Type
# Sale      1032349
# Return      35022
# Name: count, dtype: int64

# %%
conditions = [
    quantity>0,
    quantity<0,
    quantity==0
]
choices = [
    "Sale",
    "Return",
    "Zero Quantity"
]

# %%
Transaction_Status= np.select(
    conditions,
    choices,
    default="UnKnown"
)

# %%
np.unique(Transaction_Status,return_counts=True)
# Out:
# (array(['Return', 'Sale', 'UnKnown'], dtype='<U13'),
#  array([  22889, 1032349,   12133]))

# %%
np.sum(quantity==0)
# Out:
# np.int64(0)

# %%
np.sum(conditions)
# Out:
# np.int64(1055238)

# %%
np.sum(quantity<0)
# Out:
# np.int64(22889)

# %%
np.nanmean(quantity)
# Out:
# np.float64(10.022086960477163)

# %%
np.nanmin(quantity)
# Out:
# np.float64(-80995.0)

# %%
np.nanmax(quantity)
# Out:
# np.float64(80995.0)

# %%
df[df["Quantity"].isin([-80995,80995])]
# Out:
#          Invoice Transaction_Type StockCode                  Description  \
# 1060621   581483             Sale     23843  PAPER CRAFT , LITTLE BIRDIE
# 1060622  C581484           Return     23843  PAPER CRAFT , LITTLE BIRDIE
#
#          Quantity       InvoiceDate  Price  Customer ID Customer_Type  \
# 1060621   80995.0  09-12-2011 09:15   2.08      16446.0    REGISTERED
# 1060622  -80995.0  09-12-2011 09:27   2.08      16446.0    REGISTERED
#
#                 Country
# 1060621  United Kingdom
# 1060622  United Kingdom

# %%
np.nanstd(quantity)
# Out:
# np.float64(173.6818228253457)

# %%
np.sum(quantity<0)
# Out:
# np.int64(22889)

# %%
np.sum(quantity[quantity<0])
# Out:
# np.float64(-1061934.0)

# %%
abs(np.sum(quantity[quantity<0]))
# Out:
# np.float64(1061934.0)

# %%
df["Country"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
country=df["Country"].to_numpy(dtype=object)

# %%
np.unique(country)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 np.unique(country)
#
# File c:\Users\HARISH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\numpy\lib\_arraysetops_impl.py:296, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan, sorted)
#     294     if axis is not None:
#     295         normalize_axis_index(axis, ar.ndim)
# --> 296     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     297                     equal_nan=equal_nan, inverse_shape=ar.shape, axis=None,
#     298                     sorted=sorted)
#     299     return _unpack_tuple(ret)
#     301 # axis was specified and not None
#
# File c:\Users\HARISH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\numpy\lib\_arraysetops_impl.py:385, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan, inverse_shape, axis, sorted)
#     383     aux = ar[perm]
#     384 else:
# --> 385     ar.sort()
#     386     aux = ar
#     387 mask = np.empty(aux.shape, dtype=np.bool)
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
country=df["Country"].dropna().to_numpy()

# %%
np.unique(country)
# Out:
# array(['Australia', 'Austria', 'Bahrain', 'Belgium', 'Bermuda', 'Brazil',
#        'Canada', 'Channel Islands', 'Cyprus', 'Czech Republic', 'Denmark',
#        'EIRE', 'European Community', 'Finland', 'France', 'Germany',
#        'Greece', 'Hong Kong', 'Iceland', 'Israel', 'Italy', 'Japan',
#        'Korea', 'Lebanon', 'Lithuania', 'Malta', 'Netherlands', 'Nigeria',
#        'Norway', 'Poland', 'Portugal', 'RSA', 'Saudi Arabia', 'Singapore',
#        'Spain', 'Sweden', 'Switzerland', 'Thailand', 'USA',
#        'United Arab Emirates', 'United Kingdom', 'Unspecified',
#        'West Indies'], dtype=object)

# %%
np.unique(country)
# Out:
# array(['Australia', 'Austria', 'Bahrain', 'Belgium', 'Bermuda', 'Brazil',
#        'Canada', 'Channel Islands', 'Cyprus', 'Czech Republic', 'Denmark',
#        'EIRE', 'European Community', 'Finland', 'France', 'Germany',
#        'Greece', 'Hong Kong', 'Iceland', 'Israel', 'Italy', 'Japan',
#        'Korea', 'Lebanon', 'Lithuania', 'Malta', 'Netherlands', 'Nigeria',
#        'Norway', 'Poland', 'Portugal', 'RSA', 'Saudi Arabia', 'Singapore',
#        'Spain', 'Sweden', 'Switzerland', 'Thailand', 'USA',
#        'United Arab Emirates', 'United Kingdom', 'Unspecified',
#        'West Indies'], dtype=object)

# %%
len(np.unique(country))
# Out:
# 43

# %%
np.unique(country,return_counts=True)
# Out:
# (array(['Australia', 'Austria', 'Bahrain', 'Belgium', 'Bermuda', 'Brazil',
#         'Canada', 'Channel Islands', 'Cyprus', 'Czech Republic', 'Denmark',
#         'EIRE', 'European Community', 'Finland', 'France', 'Germany',
#         'Greece', 'Hong Kong', 'Iceland', 'Israel', 'Italy', 'Japan',
#         'Korea', 'Lebanon', 'Lithuania', 'Malta', 'Netherlands', 'Nigeria',
#         'Norway', 'Poland', 'Portugal', 'RSA', 'Saudi Arabia', 'Singapore',
#         'Spain', 'Sweden', 'Switzerland', 'Thailand', 'USA',
#         'United Arab Emirates', 'United Kingdom', 'Unspecified',
#         'West Indies'], dtype=object),
#  array([  1912,    938,    126,   3122,     34,     94,    228,   1663,
#           1157,     30,    817,  17844,     61,   1049,  14296,  17600,
#            663,    360,    253,    368,   1532,    582,     63,     58,
#            189,    299,   5139,     32,   1455,    535,   2608,    169,
#             10,    346,   3799,   1362,   3181,     76,    535,    500,
#         969347,    752,     54]))

# %%
np.argmax(quantity)
# Out:
# np.int64(518596)

# %%
df.iloc[np.argmax(quantity)]
# Out:
# Invoice                NaN
# Transaction_Type    Return
# StockCode              NaN
# Description            NaN
# Quantity               NaN
# InvoiceDate            NaN
# Price                  NaN
# Customer ID            NaN
# Customer_Type          NaN
# Country                NaN
# Name: 518596, dtype: object

# %%
np.nanmax(quantity)
# Out:
# np.float64(80995.0)

# %%
df.iloc[np.argmax(quantity)]
# Out:
# Invoice                NaN
# Transaction_Type    Return
# StockCode              NaN
# Description            NaN
# Quantity               NaN
# InvoiceDate            NaN
# Price                  NaN
# Customer ID            NaN
# Customer_Type          NaN
# Country                NaN
# Name: 518596, dtype: object

# %%
np.nanargmax(quantity)
# Out:
# np.int64(1060621)

# %%
df.iloc[np.nanargmax(quantity)]
# Out:
# Invoice                                  581483
# Transaction_Type                           Sale
# StockCode                                 23843
# Description         PAPER CRAFT , LITTLE BIRDIE
# Quantity                                80995.0
# InvoiceDate                    09-12-2011 09:15
# Price                                      2.08
# Customer ID                             16446.0
# Customer_Type                        REGISTERED
# Country                          United Kingdom
# Name: 1060621, dtype: object

# %%
id=np.nanargmin(quantity)

# %%
df.iloc[id]
# Out:
# Invoice                                 C581484
# Transaction_Type                         Return
# StockCode                                 23843
# Description         PAPER CRAFT , LITTLE BIRDIE
# Quantity                               -80995.0
# InvoiceDate                    09-12-2011 09:27
# Price                                      2.08
# Customer ID                             16446.0
# Customer_Type                        REGISTERED
# Country                          United Kingdom
# Name: 1060622, dtype: object

# %%
np.clip(quantity,-100,100)
# Out:
# array([12., 12., 12., ..., nan, nan, nan], shape=(1067371,))

# %%
np.where(np.isnan(quantity))
# Out:
# (array([ 518596,  518597,  518598, ..., 1067368, 1067369, 1067370],
#        shape=(12133,)),)

# %%
df.iloc[518596]
# Out:
# Invoice                NaN
# Transaction_Type    Return
# StockCode              NaN
# Description            NaN
# Quantity               NaN
# InvoiceDate            NaN
# Price                  NaN
# Customer ID            NaN
# Customer_Type          NaN
# Country                NaN
# Name: 518596, dtype: object

# %%
df.iloc[1067370]
# Out:
# Invoice                NaN
# Transaction_Type    Return
# StockCode              NaN
# Description            NaN
# Quantity               NaN
# InvoiceDate            NaN
# Price                  NaN
# Customer ID            NaN
# Customer_Type          NaN
# Country                NaN
# Name: 1067370, dtype: object

# %%
df.columns
# Out:
# Index(['Invoice', 'Transaction_Type', 'StockCode', 'Description', 'Quantity',
#        'InvoiceDate', 'Price', 'Customer ID', 'Customer_Type', 'Country'],
#       dtype='str')

# %%
df["Revenue"]=df["Quantity"]*df["Price"]

# %%
df.columns
# Out:
# Index(['Invoice', 'Transaction_Type', 'StockCode', 'Description', 'Quantity',
#        'InvoiceDate', 'Price', 'Customer ID', 'Customer_Type', 'Country',
#        'Revenue'],
#       dtype='str')

# %%
top_country=df.groupby("Country")["Revenue"].sum()

# %%
Top_10=top_country.sort_values(ascending=False).head(10)

# %%
print(Top_10)
# Out:
# Country
# United Kingdom    1.632882e+07
# EIRE              6.152291e+05
# Netherlands       5.485233e+05
# Germany           4.174299e+05
# France            3.279967e+05
# Australia         1.670616e+05
# Switzerland       9.970646e+04
# Spain             9.180816e+04
# Sweden            8.777552e+04
# Denmark           6.574109e+04
# Name: Revenue, dtype: float64

# %%
Top_Products=df.groupby("Description")["Revenue"].sum().sort_values(ascending=False).head(10)

# %%
print(Top_Products)
# Out:
# Description
# REGENCY CAKESTAND 3 TIER               327345.20
# DOTCOM POSTAGE                         322647.47
# WHITE HANGING HEART T-LIGHT HOLDER     257192.70
# JUMBO BAG RED RETROSPOT                148505.35
# PARTY BUNTING                          147870.80
# ASSORTED COLOUR BIRD ORNAMENT          131043.74
# PAPER CHAIN KIT 50'S CHRISTMAS         121523.49
# POSTAGE                                112341.00
# CHILLI LIGHTS                           84521.81
# ROTATING SILVER ANGELS T-LIGHT HLDR     73745.87
# Name: Revenue, dtype: float64

# %%
df["InvoiceDate"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df["InvoiceDate"]=pd.to_datetime(df["InvoiceDate"], format=("%d-%m-%Y %H:%M"),errors='coerce')

# %%
df["InvoiceDate"].dtype
# Out:
# dtype('<M8[us]')

# %%
df["Month"]=df['InvoiceDate'].dt.to_period("M")

# %%
df.groupby("Month")["Revenue"].sum().head(10)
# Out:
# Month
# 2009-12    796648.500
# 2010-01    622479.502
# 2010-02    531265.366
# 2010-03    763247.241
# 2010-04    587926.692
# 2010-05    613270.720
# 2010-06    677073.870
# 2010-07    573333.690
# 2010-08    654774.390
# 2010-09    851105.961
# Freq: M, Name: Revenue, dtype: float64

# %%
top_10_customers=df.groupby("Customer ID")["Revenue"].sum().sort_values(ascending=False).head(10)

# %%
print(top_10_customers)
# Out:
# Customer ID
# 18102.0    598215.22
# 14646.0    523342.07
# 14156.0    296378.14
# 14911.0    270169.49
# 17450.0    233419.39
# 13694.0    190862.96
# 17511.0    171885.98
# 12415.0    143269.29
# 16684.0    141502.25
# 15061.0    136391.48
# Name: Revenue, dtype: float64

# %%
Revenue_by_Customer_Type=df.groupby("Customer_Type")["Revenue"].sum()

# %%
print(Revenue_by_Customer_Type)
# Out:
# Customer_Type
# GUEST         2.638408e+06
# REGISTERED    1.659339e+07
# Name: Revenue, dtype: float64

# %%
Top_10_countries_by_quantity=df.groupby("Country")["Quantity"].sum().sort_values(ascending=False).head(10)

# %%
print(Top_10_countries_by_quantity)
# Out:
# Country
# United Kingdom    8660900.0
# Netherlands        381950.0
# EIRE               331154.0
# Denmark            235218.0
# Germany            224367.0
# France             184756.0
# Australia          103696.0
# Sweden              87858.0
# Switzerland         52366.0
# Spain               45134.0
# Name: Quantity, dtype: float64

# %%
No_of_orders_by_countries=df.groupby("Country")["Invoice"].nunique().sort_values(ascending=False).head(10)

# %%
print(No_of_orders_by_countries)
# Out:
# Country
# United Kingdom    49108
# Germany            1095
# EIRE                806
# France              746
# Netherlands         250
# Spain               188
# Belgium             183
# Sweden              129
# Portugal            124
# Switzerland         123
# Name: Invoice, dtype: int64

# %%
top_10_products_by_quantity_sold=df.groupby("Description")['Quantity'].sum().sort_values(ascending=False).head(10)

# %%
print(top_10_products_by_quantity_sold)
# Out:
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     108305.0
# WHITE HANGING HEART T-LIGHT HOLDER     92930.0
# ASSORTED COLOUR BIRD ORNAMENT          81087.0
# JUMBO BAG RED RETROSPOT                77928.0
# BROCADE RING PURSE                     70664.0
# PACK OF 60 PINK PAISLEY CAKE CASES     56406.0
# 60 TEATIME FAIRY CAKE CASES            54187.0
# SMALL POPCORN HOLDER                   49590.0
# PACK OF 72 RETROSPOT CAKE CASES        49283.0
# PACK OF 72 RETRO SPOT CAKE CASES       46079.0
# Name: Quantity, dtype: float64

# %%
df[df["Description"].str.contains(
    "PACK OF 72 RETRO", 
    case=False, 
    na=False
)][["StockCode", "Description"]].drop_duplicates()
# Out:
#        StockCode                       Description
# 246        21212  PACK OF 72 RETRO SPOT CAKE CASES
# 349051     21212   PACK OF 72 RETROSPOT CAKE CASES

# %%
avg_price_by_counry=df.groupby("Country")["Price"].mean()

# %%
print(avg_price_by_counry)
# Out:
# Country
# Australia                4.238661
# Austria                  4.460896
# Bahrain                  3.488016
# Belgium                  4.728901
# Bermuda                  2.491176
# Brazil                   2.726702
# Canada                   4.640746
# Channel Islands          5.445069
# Cyprus                   5.419118
# Czech Republic           2.938333
# Denmark                  2.934994
# EIRE                     7.018022
# European Community       4.820492
# Finland                  4.990095
# France                   4.697497
# Germany                  3.835424
# Greece                   3.922670
# Hong Kong               58.166056
# Iceland                  2.546087
# Israel                   3.580489
# Italy                    5.533721
# Japan                    2.162560
# Korea                    2.384762
# Lebanon                  6.182931
# Lithuania                2.615926
# Malta                   21.991940
# Netherlands              3.047593
# Nigeria                  3.415000
# Norway                  28.267979
# Poland                   3.626579
# Portugal                 6.554709
# RSA                     19.845266
# Saudi Arabia             2.411000
# Singapore               73.645665
# Spain                    5.398665
# Sweden                   6.391975
# Switzerland              3.782389
# Thailand                 2.999605
# USA                      3.282019
# United Arab Emirates     5.105060
# United Kingdom           4.562694
# Unspecified              4.532979
# West Indies              2.273519
# Name: Price, dtype: float64

# %%
rev_by_country_customertype=df.groupby(
    ['Country','Customer_Type']
)["Revenue"].sum()

# %%
print(rev_by_country_customertype)
# Out:
# Country               Customer_Type
# Australia             REGISTERED       1.670616e+05
# Austria               REGISTERED       2.317760e+04
# Bahrain               GUEST            1.507180e+03
#                       REGISTERED       1.354370e+03
# Belgium               REGISTERED       6.355499e+04
# Bermuda               GUEST            1.253140e+03
# Brazil                REGISTERED       1.411870e+03
# Canada                REGISTERED       4.883040e+03
# Channel Islands       REGISTERED       4.144371e+04
# Cyprus                REGISTERED       2.403256e+04
# Czech Republic        REGISTERED       7.077200e+02
# Denmark               REGISTERED       6.574109e+04
# EIRE                  GUEST            3.699302e+04
#                       REGISTERED       5.782360e+05
# European Community    REGISTERED       1.291750e+03
# Finland               REGISTERED       2.951445e+04
# France                GUEST            1.687130e+03
#                       REGISTERED       3.263095e+05
# Germany               REGISTERED       4.174299e+05
# Greece                REGISTERED       1.899549e+04
# Hong Kong             GUEST            1.383050e+04
# Iceland               REGISTERED       5.633320e+03
# Israel                GUEST            9.135700e+02
#                       REGISTERED       1.018780e+04
# Italy                 REGISTERED       3.066490e+04
# Japan                 REGISTERED       4.377658e+04
# Korea                 REGISTERED       9.498200e+02
# Lebanon               GUEST            1.720300e+02
#                       REGISTERED       1.693880e+03
# Lithuania             REGISTERED       6.553740e+03
# Malta                 REGISTERED       5.192220e+03
# Netherlands           REGISTERED       5.485233e+05
# Nigeria               GUEST           -1.470500e+02
#                       REGISTERED       1.403900e+02
# Norway                REGISTERED       3.924303e+04
# Poland                REGISTERED       1.052809e+04
# Portugal              GUEST            7.287500e+02
#                       REGISTERED       5.233945e+04
# RSA                   GUEST            1.435290e+03
#                       REGISTERED       1.933740e+03
# Saudi Arabia          REGISTERED       1.311700e+02
# Singapore             REGISTERED       1.315816e+04
# Spain                 REGISTERED       9.180816e+04
# Sweden                GUEST            3.540000e+02
#                       REGISTERED       8.742152e+04
# Switzerland           GUEST            6.236500e+02
#                       REGISTERED       9.908281e+04
# Thailand              REGISTERED       3.070540e+03
# USA                   REGISTERED       6.286540e+03
# United Arab Emirates  GUEST            8.769400e+02
#                       REGISTERED       9.071710e+03
# United Kingdom        GUEST            2.575871e+06
#                       REGISTERED       1.375295e+07
# Unspecified           GUEST            2.308010e+03
#                       REGISTERED       7.370460e+03
# West Indies           REGISTERED       5.364100e+02
# Name: Revenue, dtype: float64

# %%
df['Revenue_Rank']=df["Revenue"].rank(ascending=False)

# %%
df['Revenue_Rank']
# Out:
# 0           32258.0
# 1           35192.5
# 2           35192.5
# 3           26564.5
# 4          119684.5
#              ...
# 1067366         NaN
# 1067367         NaN
# 1067368         NaN
# 1067369         NaN
# 1067370         NaN
# Name: Revenue_Rank, Length: 1067371, dtype: float64

# %%
df[["Revenue", "Revenue_Rank"]].head(10)
# Out:
#    Revenue  Revenue_Rank
# 0     83.4       32258.0
# 1     81.0       35192.5
# 2     81.0       35192.5
# 3    100.8       26564.5
# 4     30.0      119684.5
# 5     39.6       82731.5
# 6     30.0      119684.5
# 7     59.5       53288.0
# 8     30.6      111656.0
# 9     45.0       70473.5

# %%
df[["Invoice", "Description", "Revenue", "Revenue_Rank"]].sort_values(
    "Revenue_Rank").head(10)
# Out:
#          Invoice                          Description    Revenue  Revenue_Rank
# 1060621   581483          PAPER CRAFT , LITTLE BIRDIE  168469.60           1.0
# 586467    541431       MEDIUM CERAMIC TOP STORAGE JAR   77183.60           2.0
# 746277    556444       PICNIC BASKET WICKER 60 PIECES   38970.00           3.0
# 238929    512771                               Manual   25111.09           4.0
# 426971    530715  ROTATING SILVER ANGELS T-LIGHT HLDR   15818.40           5.0
# 540218    537632                           AMAZON FEE   13541.33           6.5
# 511151    537632                           AMAZON FEE   13541.33           6.5
# 823106   A563185                      Adjust bad debt   11062.06           8.0
# 133499    502263                               Manual   10953.50           9.5
# 133501    502265                               Manual   10953.50           9.5

# %%
#It is oberserved that product Description such as AMAZON FEE, Adjust bad debt, Manual are not products
# for now , I'm keeping them for furthur analysis and for financial analysis this could be useful and for product
# analysis I think I should other alternate method

# %%
#I'm thinking to filter those non products out ...let me give a try

# %%
non_product = [
    "AMAZON FEE",
    "Adjust bad debt",
    "Manual",
    "POSTAGE",
    "DOTCOM POSTAGE",
    "Discount"
]

# %%
product_df = df[~df["Description"].isin(non_product)]#~used for opp of isin i.e., notin

# %%
df[df["Quantity"]>0]&df.groupby("Customer_Type")["Revenue"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[163], line 1
# ----> 1 df[df["Quantity"]>0]&df.groupby("Customer_Type")["Revenue"].mean()
#
# File c:\Users\HARISH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File c:\Users\HARISH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\arraylike.py:72, in OpsMixin.__and__(self, other)
#      70 @unpack_zerodim_and_defer("__and__")
#      71 def __and__(self, other):
# ---> 72     return self._logical_method(other, operator.and_)
#
# File c:\Users\HARISH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:9153, in DataFrame._arith_method(self, other, op)
#    9149
#    9150         self, other = self._align_for_op(other, axis, flex=True, level=None)
#    9151
#    9152         with np.errstate(all="ignore"):
# -> 9153             new_data = self._dispatch_frame_op(other, op, axis=axis)
#    9154         return self._construct_result(new_data, other=other)
#
# File c:\Users\HARISH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:9196, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    9192             #  fails in cases with empty columns reached via
#    9193             #  _frame_arith_method_with_reindex
#    9194
#    9195             # TODO operate_blockwise expects a manager of the same type
# -> 9196             bm = self._mgr.operate_blockwise(
#    9197                 right._mgr,
#    9198                 array_op,
#    9199             )
#
# File c:\Users\HARISH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\managers.py:1704, in BlockManager.operate_blockwise(self, other, array_op)
#    1700 def operate_blockwise(self, other: BlockManager, array_op) -> BlockManager:
#    1701     """
#    1702     Apply array_op blockwise with another (aligned) BlockManager.
#    1703     """
# -> 1704     return operate_blockwise(self, other, array_op)
#
# File c:\Users\HARISH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\ops.py:65, in operate_blockwise(left, right, array_op)
#      63 res_blks: list[Block] = []
#      64 for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 65     res_values = array_op(lvals, rvals)
#      66     if (
#      67         left_ea
#      68         and not right_ea
#      69         and hasattr(res_values, "reshape")
#      70         and not is_1d_only_ea_dtype(res_values.dtype)
#      71     ):
#      72         res_values = res_values.reshape(1, -1)
#
# File c:\Users\HARISH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\ops\array_ops.py:452, in logical_op(left, right, op)
#     448 rvalues = right
#     450 if should_extension_dispatch(lvalues, rvalues):
#     451     # Call the method on lvalues
# --> 452     res_values = op(lvalues, rvalues)
#     454 else:
#     455     if isinstance(rvalues, np.ndarray):
#
# File c:\Users\HARISH\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\arrays\numpy_.py:240, in NumpyExtensionArray.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#     236 if out:
#     237     kwargs["out"] = tuple(
#     238         x._ndarray if isinstance(x, NumpyExtensionArray) else x for x in out
#     239     )
# --> 240 result = getattr(ufunc, method)(*inputs, **kwargs)
#     242 if ufunc.nout > 1:
#     243     # multiple return values; re-box array-like results
#     244     return tuple(type(self)(x) for x in result)
#
# TypeError: unsupported operand type(s) for &: 'str' and 'float'

# %%
pos_df=df[df["Quantity"]>0]

# %%
pos_df.groupby("Customer_Type")["Revenue"].mean()
# Out:
# Customer_Type
# GUEST         12.86354
# REGISTERED    22.28286
# Name: Revenue, dtype: float64

# %%
df["Transaction_Type"].value_counts()
# Out:
# Transaction_Type
# Sale      1032349
# Return      35022
# Name: count, dtype: int64

# %%
df[(df["Quantity"]>10)&(df["Price"]>5)][["Invoice","Description","Quantity","Price","Revenue"]]
# Out:
#         Invoice                          Description  Quantity  Price  Revenue
# 0        489434  15CM CHRISTMAS GLASS BALL 20 LIGHTS      12.0   6.95    83.40
# 1        489434                   PINK CHERRY LIGHTS      12.0   6.75    81.00
# 2        489434                  WHITE CHERRY LIGHTS      12.0   6.75    81.00
# 13       489436             LOVE BUILDING BLOCK WORD      18.0   5.45    98.10
# 67       489438         CHARLIE + LOLA BISCUITS TINS      60.0   6.38   382.80
# ...         ...                                  ...       ...    ...      ...
# 1061513  581497           HOT WATER BOTTLE KEEP CALM      36.0   8.29   298.44
# 1061520  581497  KNITTED UNION FLAG HOT WATER BOTTLE      11.0   8.29    91.19
# 1061584  581498      PAPER CHAIN KIT 50'S CHRISTMAS       52.0   5.79   301.08
# 1061645  581498      RECIPE BOX PANTRY YELLOW DESIGN      11.0   5.79    63.69
# 1062085  581586        RED RETROSPOT ROUND CAKE TINS      24.0   8.95   214.80
#
# [7478 rows x 5 columns]
